# %%
import sys
sys.path.append('../../../bceao/')
from prix.data import *

# %%
data = Data('../../../PRIX/IPC_ANNUEL.xls')
df = data.load_data()
df.head()
# Out:
#    Date Alimentation Boissons alcoolisees, Tabac et stupefiants Habillement  \
# 0  1960          NaN                                        NaN         NaN
# 0  1960          NaN                                        NaN         NaN
# 0  1960          NaN                                        NaN         NaN
# 0  1960          NaN                                        NaN         NaN
# 0  1960          NaN                                        NaN         NaN
#
#   Ameublement Logement Sante Transport Communication Loisirs Enseignement  \
# 0         NaN      NaN   NaN       NaN           NaN     NaN          NaN
# 0         NaN      NaN   NaN       NaN           NaN     NaN          NaN
# 0         NaN      NaN   NaN       NaN           NaN     NaN          NaN
# 0         NaN      NaN   NaN       NaN           NaN     NaN          NaN
# 0         NaN      NaN   NaN       NaN           NaN     NaN          NaN
#
# ...

# %%
df.tail(20)
# Out:
#     Date Alimentation Boissons alcoolisees, Tabac et stupefiants Habillement  \
# 62  2022        133.7                                      120.1       106.7
# 62  2022        108.7                                      111.8       112.4
# 63  2023       108.99                                     112.78      115.45
# 63  2023       138.17                                     159.98      101.73
# 63  2023       140.26                                     108.28      111.79
# 63  2023        132.8                                     126.42      111.39
# 63  2023       139.13                                     107.45      101.19
# 63  2023       122.98                                     113.81      112.41
# 63  2023       123.32                                     117.56      113.26
# 63  2023       143.08                                     122.83      110.41
# 63  2023       140.54                                     117.82      120.07
# ...

# %%
data = Data('../../../PRIX/INFLATION_MOYENNE_ANNUELLE.xls')
df = data.load_data()
df.head()
# Out:
#    Date Taux d'inflation en moyenne annuelle de la fonction alimentation  \
# 0  1960                                                NaN
# 0  1960                                                NaN
# 0  1960                                                NaN
# 0  1960                                                NaN
# 0  1960                                                NaN
#
#   Taux d'inflation en moyenne annuelle de la fonction Boissons alcoolisees, Tabac et stupefiants  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   Taux d'inflation en moyenne annuelle de la fonction habillement  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# ...

# %%
df.tail(20)
# Out:
#     Date Taux d'inflation en moyenne annuelle de la fonction alimentation  \
# 62  2022                                               15.1
# 62  2022                                               11.2
# 63  2023                                                0.3
# 63  2023                                               -1.8
# 63  2023                                                6.4
# 63  2023                                                3.7
# 63  2023                                                9.6
# 63  2023                                                2.1
# 63  2023                                                4.3
# 63  2023                                               6.99
# 63  2023                                               3.51
# 64  2024                                                NaN
# 64  2024                                                NaN
# 64  2024                                                NaN
# ...

# %%
data = Data('../../../PRIX/INFLATION_GLISSEMENT_ANNUEL.xls')
df = data.load_data()
df.head()
# Out:
#       Date Taux d'inflation en glissement annuel de la fonction alimentation  \
# 7  AUG1960                                                NaN
# 7  AUG1960                                                NaN
# 7  AUG1960                                                NaN
# 7  AUG1960                                                NaN
# 7  AUG1960                                                NaN
#
#   Taux d'inflation en glissement annuel de la fonction Boissons alcoolisees, Tabac et stupefiants  \
# 7                                                NaN
# 7                                                NaN
# 7                                                NaN
# 7                                                NaN
# 7                                                NaN
#
#   Taux d'inflation en glissement annuel de la fonction habillement  \
# 7                                                NaN
# 7                                                NaN
# ...

# %%
df.tail(20)
# Out:
#         Date  \
# 752  SEP2022
# 752  SEP2022
# 764  SEP2023
# 764  SEP2023
# 764  SEP2023
# 764  SEP2023
# 764  SEP2023
# 764  SEP2023
# 764  SEP2023
# 764  SEP2023
# 764  SEP2023
# 776  SEP2024
# 776  SEP2024
# 776  SEP2024
# 776  SEP2024
# 776  SEP2024
# 776  SEP2024
# 776  SEP2024
# 776  SEP2024
# 776  SEP2024
#
#     Taux d'inflation en glissement annuel de la fonction alimentation  \
# 752                                               18.2
# 752                                                8.6
# 764                                              -4.95
# 764                                               -6.8
# 764                                               6.52
# 764                                               2.27
# 764                                               6.22
# 764                                              -0.63
# 764                                              12.45
# 764                                               4.01
# ...

# %%
data = Data('../../../PRIX/IPC_MENSUEL.xls')
df = data.load_data()
df.head()
# Out:
#       Date  Alimentation  Boissons alcoolisees, Tabac et stupefiants  \
# 7  AUG1960           NaN                                         NaN
# 7  AUG1960           NaN                                         NaN
# 7  AUG1960           NaN                                         NaN
# 7  AUG1960           NaN                                         NaN
# 7  AUG1960           NaN                                         NaN
#
#    Habillement  Ameublement  Logement  Sante  Transport  Communication  \
# 7          NaN          NaN       NaN    NaN        NaN            NaN
# 7          NaN          NaN       NaN    NaN        NaN            NaN
# 7          NaN          NaN       NaN    NaN        NaN            NaN
# 7          NaN          NaN       NaN    NaN        NaN            NaN
# 7          NaN          NaN       NaN    NaN        NaN            NaN
#
#    Loisirs  Enseignement  Hotels et restaurants  Autres biens et services  \
# ...
