# %%
import sys
sys.path.append('./macrobceao/')
from macrobceao.bceao import *

data = Data('prix mensuels uemoa sans meta.xls')
df = data.load_data()
df.head()
# Out:
# ['Alimentation', 'Boissons alcoolisees, Tabac et stupefiants', 'Habillement', 'Ameublement', 'Logement', 'Sante', 'Transport', 'Communication', 'Loisirs', 'Enseignement', 'Hotels et restaurants', 'Autres biens et services', 'Ensemble']
# ['Alimentation', 'Boissons alcoolisees, Tabac et stupefiants', 'Habillement', 'Ameublement', 'Logement', 'Sante', 'Transport', 'Communication', 'Loisirs', 'Enseignement', 'Hotels et restaurants', 'Autres biens et services', 'Ensemble']
# ['Alimentation', 'Boissons alcoolisees, Tabac et stupefiants', 'Habillement', 'Ameublement', 'Logement', 'Sante', 'Transport', 'Communication', 'Loisirs', 'Enseignement', 'Hotels et restaurants', 'Autres biens et services', 'Ensemble']
# ['Alimentation', 'Boissons alcoolisees, Tabac et stupefiants', 'Habillement', 'Ameublement', 'Logement', 'Sante', 'Transport', 'Communication', 'Loisirs', 'Enseignement', 'Hotels et restaurants', 'Autres biens et services', 'Ensemble']
# ...

# %%
df.shape
# Out:
# (7020, 18)

# %%
df.tail(20)
# Out:
#         Date  Alimentation  Boissons alcoolisees, Tabac et stupefiants  \
# 752  SEP2022        144.10                                      121.70
# 752  SEP2022        134.60                                      119.60
# 764  SEP2023         99.95                                      112.12
# 764  SEP2023        139.99                                      156.47
# 764  SEP2023        143.12                                      108.94
# 764  SEP2023        136.21                                      125.58
# 764  SEP2023        138.74                                      107.50
# 764  SEP2023        126.25                                      112.40
# 764  SEP2023        135.11                                      118.02
# 764  SEP2023        149.92                                      123.16
# 764  SEP2023        136.92                                      118.67
# 776  SEP2024           NaN                                         NaN
# ...
