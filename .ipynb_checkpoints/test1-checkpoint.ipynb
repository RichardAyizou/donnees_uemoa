# %%
import sys
sys.path.append('./macrobceao/')
from macrobceao.bceao import *

# %%
data = Data('exportIndicateurs.xls')
df = data.load_data()

# %%
data.diagnostic_statistics()
# Out:
# ===== ******************** =====
# Dimensions des données
# ---
# Nombre de lignes : 1170
# Nombre de colonnes : 55
#
#
#
# ===== ******************** =====
# Période de l'étude
# ---
# Début : 1960
# Fin : 2024
# Taille : 65
#
#
#
# ===== ******************** =====
# Pays inclus dans l'étude
# ---
# Nombre de pays : 9
# Liste des pays : ["COTE D'IVOIRE", 'BENIN', 'BURKINA FASO', 'MALI', 'NIGER', 'SENEGAL', 'GUINEE BISSAU', 'TOGO', 'ENSEMBLE UMOA']
#
#
#
# ===== ******************** =====
# Données manquantes par variable
# ---
# [('Annee', 0), ('PIB nominal (en milliards de FCFA)', 100), ('Poids (%) : Secteur primaire', 756), ('Secteur secondaire', 756), ('Secteur tertiaire', 756), ('Taux de croissance reel du PIB (en %)', 558), ('Contribution a la croissance : Primaire', 756), ('Secondaire', 756), ('Tertiaire', 756), ('Epargne interieure (en milliards de FCFA)', 102), ("Taux d'epargne interieure (en %)", 560), ("Taux d'epargne interieure publique (en %)", 756), ('Investissement (en milliards de F CFA)', 152), ("Taux d'investissement (en %)", 560), ("Taux d'investissement public (en %)", 756), ("Taux d'inflation moyen annuel (IPC) (en %)", 710), ("Taux d'inflation en glissement annuel (fin decembre) (en %)", 702), ('Recettes totales et dons (R1)', 92), ('Recettes totales hors dons (R2)', 92), ('Recettes fiscales', 92), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Depenses totales et prets nets (D1)', 92), ('Depenses courantes (D3)', 92), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Investissements sur ressources internes', 756), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Solde primaire de base sur recettes fiscales (en %)', 756), ('Solde budgetaire de base', 756), ('Solde budgetaire global, avec dons (base engagement) (R1 - D1)', 92), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Solde budgetaire global, hors dons (base engagement) (R2 - D1)', 92), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Encours de la dette', 198), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Service de la dette regle', 198), ('interets', 198), ('Exportations de biens FOB :', 360), ('Importations de biens FOB', 360), ('Balance des biens', 360), ('Compte des transactions courantes (1+2+3)', 360), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Balance courante hors dons publics', 828), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('SOLDE GLOBAL apres ajustement', 940), ('Pour memoire : financement exceptionnel', 828), ("Degre d'ouverture (Export B&S+Import B&S)/PIB (en %)", 828), ('Agregats de Monnaie - Actifs exterieurs nets', 810), ('Agregats de Monnaie - Creances interieures', 810), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Agregats de Monnaie - Creances interieures - Creances sur les autres secteurs', 810), ('(en % du PIB)', (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    756
# (en % du PIB)    828
# (en % du PIB)    828
# (en % du PIB)    756
# (en % du PIB)    756
# dtype: int64), ('Agregats de Monnaie - Masse monetaire (M2)', 810), ('Atifs exterieurs nets total - BCEAO - Creances sur les non-residents - Avoirs officiels de reserve', 1170), ("Taux de couverture de l'emission monetaire", 1124), ('Country', 0)]

# %%
df.head()
# Out:
#   Annee PIB nominal (en milliards de FCFA) Poids (%) : Secteur primaire  \
# 0  1960                            140,700                          NaN
# 1  1961                            159,300                          NaN
# 2  1962                            166,100                          NaN
# 3  1963                            195,900                          NaN
# 4  1964                            237,100                          NaN
#
#   Secteur secondaire Secteur tertiaire Taux de croissance reel du PIB (en %)  \
# 0                NaN               NaN                                   NaN
# 1                NaN               NaN                                   NaN
# 2                NaN               NaN                                   NaN
# 3                NaN               NaN                                   NaN
# 4                NaN               NaN                                   NaN
#
#   Contribution a la croissance : Primaire Secondaire Tertiaire  \
# 0                                     NaN        NaN       NaN
# 1                                     NaN        NaN       NaN
# 2                                     NaN        NaN       NaN
# 3                                     NaN        NaN       NaN
# 4                                     NaN        NaN       NaN
#
#   Epargne interieure (en milliards de FCFA)  ...  \
# 0                                    31,300  ...
# 1                                    31,900  ...
# 2                                    27,700  ...
# 3                                    43,400  ...
# 4                                    32,200  ...
#
#   Degre d'ouverture (Export B&S+Import B&S)/PIB (en %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Agregats de Monnaie - Actifs exterieurs nets  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Agregats de Monnaie - Creances interieures (en % du PIB)  \
# 0                                        NaN           NaN
# 1                                        NaN           NaN
# 2                                        NaN           NaN
# 3                                        NaN           NaN
# 4                                        NaN           NaN
#
#   Agregats de Monnaie - Creances interieures - Creances sur les autres secteurs  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   (en % du PIB) Agregats de Monnaie - Masse monetaire (M2)  \
# 0           NaN                                        NaN
# 1           NaN                                        NaN
# 2           NaN                                        NaN
# 3           NaN                                        NaN
# 4           NaN                                        NaN
#
#   Atifs exterieurs nets total - BCEAO - Creances sur les non-residents - Avoirs officiels de reserve  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Taux de couverture de l'emission monetaire        Country
# 0                                        NaN  COTE D'IVOIRE
# 1                                        NaN  COTE D'IVOIRE
# 2                                        NaN  COTE D'IVOIRE
# 3                                        NaN  COTE D'IVOIRE
# 4                                        NaN  COTE D'IVOIRE
#
# [5 rows x 55 columns]
