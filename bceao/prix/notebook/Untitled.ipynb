# %%
import sys
sys.path.append('../../../bceao/')
from prix.data import *

data = Data('../../../PRIX/IPC_MENSUEL.xls')
df = data.load_data()
df.head()
# Out:
#       Date Alimentation Boissons alcoolisees, Tabac et stupefiants  \
# 0  JAN1960          NaN                                        NaN
# 0  JAN1960          NaN                                        NaN
# 0  JAN1960          NaN                                        NaN
# 0  JAN1960          NaN                                        NaN
# 0  JAN1960          NaN                                        NaN
#
#   Habillement Ameublement Logement Sante Transport Communication Loisirs  \
# 0         NaN         NaN      NaN   NaN       NaN           NaN     NaN
# 0         NaN         NaN      NaN   NaN       NaN           NaN     NaN
# 0         NaN         NaN      NaN   NaN       NaN           NaN     NaN
# 0         NaN         NaN      NaN   NaN       NaN           NaN     NaN
# 0         NaN         NaN      NaN   NaN       NaN           NaN     NaN
#
#   Enseignement Hotels et restaurants Autres biens et services Ensemble Mois  \
# ...

# %%
df.tail(20)
# Out:
#         Date Alimentation Boissons alcoolisees, Tabac et stupefiants  \
# 779  DEC2024          NaN                                        NaN
# 779  DEC2024          NaN                                        NaN
# 772  MAY2024       113.36                                     110.22
# 775  AUG2024          NaN                                        NaN
# 772  MAY2024        144.6                                      161.6
# 775  AUG2024          NaN                                        NaN
# 772  MAY2024        149.2                                      109.9
# 775  AUG2024          NaN                                        NaN
# 772  MAY2024        139.0                                      128.8
# 775  AUG2024          NaN                                        NaN
# 772  MAY2024        143.3                                      108.2
# 775  AUG2024          NaN                                        NaN
# 772  MAY2024        124.0                                      130.4
# ...
