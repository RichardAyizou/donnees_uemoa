# %%
import sys
sys.path.append('./macrobceao/')
from macrobceao.bceao import *

# %%
data = Data('exportIndicateurs compta nat bfa.csv', 'csv')
df = data.load_data()

# %%
data.diagnostic_statistics()
# Out:
# ===== ******************** =====
# Dimensions des données
# ---
# Nombre de lignes : 102
# Nombre de colonnes : 57
#
#
#
# ===== ******************** =====
# Période de l'étude
# ---
# Début : 1960-01-01 00:00:00
# Fin : 2010-01-01 00:00:00
# Taille : 51
#
#
#
# ===== ******************** =====
# Pays inclus dans l'étude
# ---
# Nombre de pays : 1
# Liste des pays : ['BURKINA FASO']
#
#
#
# ===== ******************** =====
# Données manquantes par variable
# ---
# [('Date', 0), ("Valeur ajoutee de l'agriculture a prix constant", 52), ('valeur ajoutee du secteur des extractions', 40), ('valeur ajoutee des industries', 0), ('Valeur ajoutee des gaz, eau, electricite', 40), ('Valeur ajoutee des bâtiments et travaux publics aux PIB', 40), ('valeur ajoutee du commerce', 40), ('Valeur ajoutee des transports, entrepots et communications', 40), ('valeur ajoutee des autres services marchands', 40), ("Droits et taxes a l'importation", 0), ("Droits et taxes � l'importation � prix constant", 50), ('PIB marchand', 0), ('PIB marchand a prix constant', 50), ('PIB non marchand', 0), ('PIB non marchand a prix constant', 50), ('Produit interieur brut aux coûts des facteurs calcule', 0), ('Produit interieur brut aux coûts des facteurs a prix constant', 50), ('PRODUIT INTERIEUR BRUT (PIB) NOMINAL', 0), ('PIB a prix constant', 0), ('Consommation finale', 0), ('Consommation finale a prix constant', 0), ('Consommation publique', 0), ('Consommation publique a prix constant', 0), ('Consommation privee', 0), ('Consommation privee a prix constant', 0), ('Formation brute de capital fixe (FBCF)', 0), ('Formation brute de capital fixe a prix constant', 20), ('Formation brute de capital fixe privee', 52), ('Formation brute de capital fixe publique', 52), ('Variation de stocks', 0), ('Variation de stocks a prix constant', 38), ('Exportation des biens et services non facteurs', 0), ('Exportation des biens et services non facteurs a prix constant', 0), ('Importation des biens et services non facteurs', 0), ('Importation des biens et services non facteurs a prix constant', 0), ('Deflateur du PIB', 44), ('Produit national brut', 0), ('Epargne interieure', 0), ('Investissement', 0), ('valeur ajoutee du secteur primaire', 20), ('valeur ajoutee du secteur primaire a prix constant', 6), ('valeur ajoutee du secteur secondaire', 20), ('valeur ajoutee du secteur secondaire a prix constant', 28), ('valeur ajoutee du secteur tertiaire', 20), ('valeur ajoutee a prix constant du secteur tertiaire', 6), ('Taux de croissance du PIB r�el', 60), ("Taux d'investissement", 60), ("Taux d'epargne interieure", 60), ('Poids (%)�: Secteur primaire', 82), ('Secteur secondaire', 82), ('Secteur tertiaire', 82), ('Contribution a la croissance : Primaire', 82), ('Contribution a la croissance : Secondaire', 82), ('Contribution a la croissance : Tertiaire', 82), ("Taux d'epargne interieure publique", 82), ("Taux d'investissement public", 82), ('Country', 0)]

# %%
data.diagnostic_plot([
    'Investissement', 
    'Produit national brut'
])
# Out:
# <div>                            <div id="eaf68709-8211-48bf-9d37-1878ea52f6d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e